# %%
# !pip install mlxtend
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.4 MB 325.1 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/1.4 MB 465.5 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 726.2 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.1/1.4 MB 708.1 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.1/1.4 MB 708.1 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.1/1.4 MB 708.1 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.4/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.4 MB 1.0 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 950.1 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import csv
from mlxtend.preprocessing import TransactionEncoder

from mlxtend.frequent_patterns import apriori,association_rules

# %%
dataset =[]
with open(r"Mall_Customers.csv") as file:
    reader = csv.reader(file,delimiter=',')
    for row in reader:
        dataset+=[row]

# %%
dataset
# Out:
# []

# %%
te = TransactionEncoder()
x = te.fit_transform(dataset)
x
# Out:
# array([[False, False, False, ...,  True, False,  True],
#        [ True, False, False, ..., False,  True, False],
#        [False,  True, False, ..., False,  True, False],
#        ...,
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False,  True, False]])

# %%
df = pd.DataFrame(x,columns=te.columns_)
df
# Out:
#       0001   0002   0003   0004   0005   0006   0007   0008   0009   0010  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1     True  False  False  False  False  False  False  False  False  False
# 2    False   True  False  False  False  False  False  False  False  False
# 3    False  False   True  False  False  False  False  False  False  False
# 4    False  False  False   True  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 196  False  False  False  False  False  False  False  False  False  False
# 197  False  False  False  False  False  False  False  False  False  False
# 198  False  False  False  False  False  False  False  False  False  False
# 199  False  False  False  False  False  False  False  False  False  False
# 200  False  False  False  False  False  False  False  False  False  False
#
#      ...     97     98     99    Age  Annual Income (k$)  CustomerID  Female  \
# ...

# %%
freq_itemset = apriori(df,min_support=0.01,use_colnames=True)
freq_itemset
# Out:
#       support          itemsets
# 0    0.019900             (103)
# 1    0.014925              (13)
# 2    0.019900              (14)
# 3    0.024876              (15)
# 4    0.019900              (16)
# ..        ...               ...
# 187  0.014925        (93, Male)
# 188  0.014925  (Female, 73, 30)
# 189  0.014925  (Female, 31, 40)
# 190  0.014925  (Female, 42, 49)
# 191  0.014925  (Female, 60, 50)
#
# [192 rows x 2 columns]

# %%
rules = association_rules(freq_itemset,metric='confidence',min_threshold=0.21)
rules
# Out:
#       antecedents   consequents  antecedent support  consequent support  \
# 0           (103)      (Female)            0.019900            0.557214
# 1            (15)        (Male)            0.024876            0.437811
# 2            (16)      (Female)            0.019900            0.557214
# 3            (17)      (Female)            0.024876            0.557214
# 4            (18)      (Female)            0.034826            0.557214
# ..            ...           ...                 ...                 ...
# 129  (Female, 60)          (50)            0.034826            0.059701
# 130  (Female, 50)          (60)            0.054726            0.059701
# 131      (60, 50)      (Female)            0.014925            0.557214
# 132          (60)  (Female, 50)            0.059701            0.054726
# 133          (50)  (Female, 60)            0.059701            0.034826
#
#       support  confidence      lift  representativity  leverage  conviction  \
# ...

# %%
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0       (103)    (Female)            0.019900            0.557214  0.019900
# 1        (15)      (Male)            0.024876            0.437811  0.019900
# 2        (16)    (Female)            0.019900            0.557214  0.019900
# 3        (17)    (Female)            0.024876            0.557214  0.019900
# 4        (18)    (Female)            0.034826            0.557214  0.014925
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    1.000000  1.794643               1.0  0.008812         inf
# 1    0.800000  1.827273               1.0  0.009010    2.810945
# 2    1.000000  1.794643               1.0  0.008812         inf
# 3    0.800000  1.435714               1.0  0.006039    2.213930
# 4    0.428571  0.769133               1.0 -0.004480    0.774876
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0       0.451777  0.035714   1.000000    0.517857
# ...

# %%
rules[rules['antecedents']=={'cake'}]['consequents']
# Out:
# Series([], Name: consequents, dtype: object)
